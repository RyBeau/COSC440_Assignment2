# %%
from google.colab import drive
drive.mount('/content/gdrive')

from importlib import reload

import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/COSC440/COSC440_Assignment2')

import assignment
import assignment_tests
import convolution
import preprocess


reload(assignment)
reload(preprocess)
reload(convolution)
reload(assignment_tests)

#assignment.main("/content/gdrive/My Drive/Colab Notebooks/COSC440/COSC440_Assignment2/CIFAR_data/")

# !python /content/gdrive/My\ Drive/Colab\ Notebooks/COSC440/COSC440_Assignment2/assignment_tests.py
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# 2021-08-27 09:50:20.933102: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-27 09:50:20.942029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-08-27 09:50:20.942860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
